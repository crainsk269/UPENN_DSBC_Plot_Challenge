# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# 1. Initially, we looked data which showed results from 10 different drugs on a combination of both male and female mice which varied in weight. Of these drugs tested, the average mouse weight was 27g, while the average weight for the other two drugs was 19g (Capomulin and Ramicane). Capomulin and Ramicane both finished in the top two amongst all other drugs for Tumor Volume (mm3) mean, median, var, std, and sem; showing that they were more successful than the remaining eight drugs.
#
# 2. Of the original 249 test subjects, mouse g989 had duplicate values within the Timepoint and was therefore excluded from further analysis in our studies.
#
# 3. Male and female populations were almost equal; 51% and 49% respectively. Additional analysis on male only and female only results was not conducted during our research.
#
# 4. Four drugs were selected for outlier analysis: Capomulin, Ramicane, Infubinol, and Ceftamin. Infubinol was the only one of the four which had outliers, it also had the highest numbers in all five categories of mean, median, var, std, and sem.
#
# 5. From all of the analysis that we conducted, Capomulin and Ramicane showed to be the two most succesful drugs at treating tumors in mice.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
mouse_study_df = pd.merge(study_results, mouse_metadata, how="left", on="Mouse ID")

# Display the data table for preview
mouse_study_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice.
mouse_count = mouse_study_df['Mouse ID'].nunique()
mouse_count
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
index_mouse_study_df = mouse_study_df.set_index('Mouse ID')
index_mouse_study_df.loc['g989']
# Out:
#           Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# Mouse ID
# g989              0           45.000000                 0     Propriva
# g989              0           45.000000                 0     Propriva
# g989              5           48.786801                 0     Propriva
# g989              5           47.570392                 0     Propriva
# g989             10           51.745156                 0     Propriva
# g989             10           49.880528                 0     Propriva
# g989             15           51.325852                 1     Propriva
# g989             15           53.442020                 0     Propriva
# g989             20           55.326122                 1     Propriva
# g989             20           54.657650                 1     Propriva
# g989             25           56.045564                 1     Propriva
# g989             30           59.082294                 1     Propriva
# ...

# %%
# Optional: Get all the data for the duplicate mouse ID. 
mouse_study_df[mouse_study_df['Mouse ID']=='g989']
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
mouse_study_clean = index_mouse_study_df.drop(['g989'])
mouse_study_clean = mouse_study_clean.reset_index()
mouse_study_clean
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1875     r944         45           41.581521                 2    Capomulin
# 1876     u364         45           31.023923                 3    Capomulin
# 1877     p438         45           61.433892                 1     Ceftamin
# 1878     x773         45           58.634971                 4      Placebo
# 1879     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice in the clean DataFrame.
mouse_count_clean = mouse_study_clean['Mouse ID'].nunique()
mouse_count_clean
# Out:
# 248

# %%
mouse_mean = mouse_study_clean.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].mean()

# Check mean
mouse_mean.sort_values()
# Out:
# Drug Regimen
# Ramicane     40.216745
# Capomulin    40.675741
# Propriva     52.320930
# Ceftamin     52.591172
# Infubinol    52.884795
# Zoniferol    53.236507
# Placebo      54.033581
# Stelasyn     54.233149
# Naftisol     54.331565
# Ketapril     55.235638
# Name: Tumor Volume (mm3), dtype: float64

# %%
mouse_median = mouse_study_clean.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].median()

#Check median
mouse_median.sort_values()
# Out:
# Drug Regimen
# Ramicane     40.673236
# Capomulin    41.557809
# Propriva     50.446266
# Ceftamin     51.776157
# Zoniferol    51.818479
# Infubinol    51.820584
# Placebo      52.288934
# Stelasyn     52.431737
# Naftisol     52.509285
# Ketapril     53.698743
# Name: Tumor Volume (mm3), dtype: float64

# %%
mouse_var = mouse_study_clean.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].var()

# Check var
mouse_var.sort_values()
# Out:
# Drug Regimen
# Ramicane     23.486704
# Capomulin    24.947764
# Ceftamin     39.290177
# Infubinol    43.128684
# Propriva     43.852013
# Zoniferol    48.533355
# Stelasyn     59.450562
# Placebo      61.168083
# Naftisol     66.173479
# Ketapril     68.553577
# Name: Tumor Volume (mm3), dtype: float64

# %%
mouse_std = mouse_study_clean.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].std()

# Check std
mouse_std.sort_values()
# Out:
# Drug Regimen
# Ramicane     4.846308
# Capomulin    4.994774
# Ceftamin     6.268188
# Infubinol    6.567243
# Propriva     6.622085
# Zoniferol    6.966589
# Stelasyn     7.710419
# Placebo      7.821003
# Naftisol     8.134708
# Ketapril     8.279709
# Name: Tumor Volume (mm3), dtype: float64

# %%
mouse_sem = mouse_study_clean.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].sem()

# Check sem
mouse_sem.sort_values()
# Out:
# Drug Regimen
# Ramicane     0.320955
# Capomulin    0.329346
# Ceftamin     0.469821
# Infubinol    0.492236
# Zoniferol    0.516398
# Propriva     0.544332
# Stelasyn     0.573111
# Placebo      0.581331
# Naftisol     0.596466
# Ketapril     0.603860
# Name: Tumor Volume (mm3), dtype: float64

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen:
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
mouse_mean = mouse_study_clean.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].mean()
mouse_median = mouse_study_clean.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].median()
mouse_var = mouse_study_clean.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].var()
mouse_std = mouse_study_clean.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].std()
mouse_sem = mouse_study_clean.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].sem()

# Assemble the resulting series into a single summary DataFrame.
drug_regimen_stats = pd.DataFrame({'Mean Tumor Volume': mouse_mean,
                                 'Median Tumor Volume': mouse_median,
                                 'Tumor Volume Variance': mouse_var,
                                 'Tumor Volume Std. Dev.': mouse_std,
                                 'Tumor Volume Std. Err.': mouse_sem})


# Minor data wrangling
drug_regimen_stats.index.name = 'Drug Regimen'

# Display the DataFrame
drug_regimen_stats
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line
mouse_study_aggregate = mouse_study_clean.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].agg(['mean', 'median', 'var', 'std', 'sem'])
mouse_study_aggregate
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
mouse_timepoint = mouse_study_clean.groupby(['Drug Regimen'])['Timepoint'].count()
mouse_timepoint.sort_values(ascending=False).plot.bar()

# Label
plt.ylabel('# of Observed Mouse Timepoints')

# Display
plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
drug_regimen_bar = mouse_timepoint.sort_values(ascending=False)

# Bar plot
plt.bar(drug_regimen_bar.index, drug_regimen_bar.values, align="center")

# Labels and ticks
plt.xlabel('Drug Regimen')
plt.ylabel('# of Observed Mouse Timepoints')
plt.xticks(rotation='vertical')
plt.xlim(-0.75, len(drug_regimen_bar)-0.25)
plt.tight_layout()

# Display
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
sex = mouse_study_clean.groupby('Sex')['Sex'].value_counts()
labels = ['Female', 'Male']
# colors = ['darkorange','skyblue']

plt.pie(sex, labels=labels, autopct="%1.1f%%", startangle=185)
# Out:
# ([<matplotlib.patches.Wedge at 0x16bde425f90>,
# ...
#  [Text(0.06287182338377972, -1.0982017728197306, 'Female'),
#   Text(-0.06287182338377958, 1.0982017728197306, 'Male')],
#  [Text(0.03429372184569803, -0.599019148810762, '49.0%'),
#   Text(-0.034293721845697955, 0.599019148810762, '51.0%')])

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
plt.pie(sex, labels=('Female', 'Male'), autopct='%1.1f%%', startangle=185)
plt.ylabel('Sex')

# Display
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
last_timepoint = mouse_study_clean.groupby(['Mouse ID'])['Timepoint'].max()
last_timepoint_df = pd.DataFrame(last_timepoint)
# last_timepoint_df

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
last_timepoint_merged = pd.merge(last_timepoint_df, mouse_study_clean, on=['Mouse ID', 'Timepoint'])
last_timepoint_merged
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0       a203         45           67.973419                 2    Infubinol
# 1       a251         45           65.525743                 1    Infubinol
# 2       a262         45           70.717621                 4      Placebo
# 3       a275         45           62.999356                 3     Ceftamin
# 4       a366         30           63.440686                 1     Stelasyn
# ..       ...        ...                 ...               ...          ...
# 243     z435         10           48.710661                 0     Propriva
# 244     z578         45           30.638696                 0     Ramicane
# 245     z581         45           62.754451                 3    Infubinol
# 246     z795         45           65.741070                 3     Naftisol
# 247     z969         45           73.867845                 4     Naftisol
#
#         Sex  Age_months  Weight (g)
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
drugs = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
tumor_volumes = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    # Locate the rows which contain mice on each drug and get the tumor volumes
for drug in drugs:
    tumor_df = last_timepoint_merged.loc[last_timepoint_merged['Drug Regimen'] == drug]['Tumor Volume (mm3)']
    
    tumor_volumes.append(tumor_df)
    
    quartiles = tumor_df.quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    
    outliers = tumor_df.loc[(tumor_df >= upper_bound) | (tumor_df <= lower_bound)]
    
    print(f"{drug}'s potential outliers: ", outliers)
    
    print('---------------------------------------------')
# Out:
# Capomulin's potential outliers:  Series([], Name: Tumor Volume (mm3), dtype: float64)
# ---------------------------------------------
# Ramicane's potential outliers:  Series([], Name: Tumor Volume (mm3), dtype: float64)
# ---------------------------------------------
# Infubinol's potential outliers:  31    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# ---------------------------------------------
# Ceftamin's potential outliers:  Series([], Name: Tumor Volume (mm3), dtype: float64)
# ---------------------------------------------

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
tumor_distribution = dict(marker='o', markerfacecolor='r', markersize=12, markeredgecolor='black')

# Box plot
plt.boxplot(tumor_volumes, flierprops=tumor_distribution)

# Title and labels
plt.title('Tumor Volumes by Drug Types')
plt.xlabel('Drug Regimen')
plt.ylabel('Final Tumor Volume (mm3)')
plt.xticks([1, 2, 3, 4], drugs)

# Display
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
mouse_subject = mouse_study_clean.loc[mouse_study_clean['Mouse ID'] == 'l509']

# Line ploto
plt.plot(mouse_subject['Timepoint'], mouse_subject['Tumor Volume (mm3)'])

# Title and labels
plt.title(f"Capomulin treatment of mouse l509")
plt.xlabel('Timepoint (days)')
plt.ylabel('Tumor Volume (mm3)')

# Display
plt.show()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
mouse_weight = mouse_study_clean.groupby(['Mouse ID', 'Drug Regimen']).agg({'Tumor Volume (mm3)': 'mean', 'Weight (g)': 'mean'}).reset_index()
cap_reg = mouse_weight.loc[mouse_weight['Drug Regimen'] == 'Capomulin']

# Scatter plot
plt.scatter(cap_reg['Weight (g)'], cap_reg['Tumor Volume (mm3)'], marker='o')

#Title and labels
plt.title('Capomulin (Mouse Weight vs Average Tumor Volume)')
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')

# Display
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen

# Correlation coefficient
corr_coef = cap_reg['Tumor Volume (mm3)'].corr(cap_reg['Weight (g)'])
print(f'The correlation between mouse weight and average tumor volume is {corr_coef:.2f}')

# Linear regression
slope, intercept, rvalue, pvalue, stderr = linregress(cap_reg['Weight (g)'], cap_reg['Tumor Volume (mm3)'])
regress_values = slope * cap_reg['Weight (g)'] + intercept
plt.plot(cap_reg['Weight (g)'], regress_values, 'r')

# Scatter plot
plt.scatter(cap_reg['Weight (g)'], cap_reg['Tumor Volume (mm3)'], marker='o')

# Title and labels
plt.title('Mouse Weight and Average Tumor Volume')
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')

# Display
plt.show()
# Out:
# The correlation between mouse weight and average tumor volume is 0.84
